# %%
import numpy as np
from mesa import Agent, Model
from mesa.time import RandomActivation
from mesa.space import ContinuousSpace
import matplotlib.pyplot as plt
import random

# Gravitational centers (position, strength) for sweet spots
GRAVITY_CENTERS = [
    (np.array([30, 30]), 1.0),  # Strongest sweet spot
    (np.array([70, 70]), 0.7),  # Medium sweet spot
    (np.array([50, 20]), 0.5)   # Weakest sweet spot
]
G_NORMAL = 0.1  # Scaled gravitational constant
G_MICRO = 0     # Microgravity

class PreyAgent(Agent):
    def __init__(self, unique_id, model):
        self.unique_id = unique_id
        self.model = model
        self.pos = None
        self.resources = 5  # Resources provided when engulfed

    def step(self):
        if self.model.G != G_MICRO:
            nearest_pos, strength = min(
                GRAVITY_CENTERS, key=lambda m: np.linalg.norm(self.pos - m[0])
            )
            r = np.linalg.norm(self.pos - nearest_pos)
            if r > 0:
                force = self.model.G * strength * 0.05 / (r**2)
                direction = (nearest_pos - self.pos) / r
                vortex = np.array([-direction[1], direction[0]]) * 0.1
                self.pos += (direction * force + vortex) * 0.1
        self.pos = np.clip(self.pos, 0, 100)

class PredatorAgent(Agent):
    def __init__(self, unique_id, model):
        self.unique_id = unique_id
        self.model = model
        self.pos = None
        self.resources = 0
        self.motility = np.random.uniform(0.5, 1.5)
        self.efficiency = np.random.uniform(0.5, 1.5)
        self.has_organelle = False

    def step(self):
        # Movement
        if self.model.G != G_MICRO:
            nearest_pos, strength = min(
                GRAVITY_CENTERS, key=lambda m: np.linalg.norm(self.pos - m[0])
            )
            r = np.linalg.norm(self.pos - nearest_pos)
            if r > 0:
                force = self.model.G * strength / (r**2)
                direction = (nearest_pos - self.pos) / r
                vortex = np.array([-direction[1], direction[0]]) * 0.2
                self.pos += (direction * force + vortex) * self.motility * 0.1
        else:
            self.pos += np.random.uniform(-1.0, 1.0, 2)

        # Resource consumption
        nearest_pos, _ = min(GRAVITY_CENTERS, key=lambda m: np.linalg.norm(self.pos - m[0]))
        r = np.linalg.norm(self.pos - nearest_pos)
        resource_density = max(0, 10 - r / 5)
        gravity_factor = 0.5 if self.model.G == G_MICRO else 1.0
        self.resources += resource_density * self.efficiency * gravity_factor

        # Endosymbiosis
        neighbors = self.model.space.get_neighbors(self.pos, 2, include_center=False)
        for neighbor in neighbors:
            if isinstance(neighbor, PreyAgent) and not self.has_organelle:
                self.has_organelle = True
                self.resources += neighbor.resources
                self.efficiency *= 1.5
                self.model.space.remove_agent(neighbor)
                self.model.schedule.remove(neighbor)
                self.model.endosymbiosis_events += 1
                break

        # Reproduction
        if self.resources > 50 and random.random() < 0.1:
            offspring = PredatorAgent(self.model.next_id(), self.model)
            offspring.motility = self.motility + np.random.uniform(-0.1, 0.1)
            offspring.efficiency = self.efficiency + np.random.uniform(-0.1, 0.1)
            desired_pos = self.pos + np.random.uniform(-1, 1, 2)
            clipped_pos = np.clip(desired_pos, 0, 100)
            self.model.schedule.add(offspring)
            try:
                self.model.space.place_agent(offspring, clipped_pos)
            except Exception as e:
                print(f"Error placing agent {offspring.unique_id} at {clipped_pos}: {e}")
                # Fallback: Place at parent's position
                self.model.space.place_agent(offspring, self.pos)
            self.resources -= 25

        self.pos = np.clip(self.pos, 0, 100)

class GravityCompetitionModel(Model):
    def __init__(self, N_predators, N_prey, G):
        super().__init__()
        self.random = random.Random()
        self.G = G
        self.space = ContinuousSpace(100, 100, torus=False)
        self.schedule = RandomActivation(self)
        self.endosymbiosis_events = 0
        self.next_id_val = N_predators + N_prey

        for i in range(N_predators):
            agent = PredatorAgent(i, self)
            self.schedule.add(agent)
            initial_pos = np.array([np.random.uniform(0, 100), np.random.uniform(0, 100)])
            self.space.place_agent(agent, initial_pos)

        for i in range(N_prey):
            prey = PreyAgent(N_predators + i, self)
            self.schedule.add(prey)
            initial_pos = np.array([np.random.uniform(0, 100), np.random.uniform(0, 100)])
            self.space.place_agent(prey, initial_pos)

    def next_id(self):
        self.next_id_val += 1
        return self.next_id_val - 1

    def step(self):
        self.schedule.step()

def run_simulation(gravity, label, steps=100):
    model = GravityCompetitionModel(50, 50, gravity)
    for _ in range(steps):
        model.step()

    predators = [a for a in model.schedule.agents if isinstance(a, PredatorAgent)]
    positions = [a.pos for a in predators]
    x, y = zip(*positions)
    resources = [a.resources for a in predators]
    organelle_count = sum(1 for a in predators if a.has_organelle)
    avg_motility = np.mean([a.motility for a in predators])
    avg_efficiency = np.mean([a.efficiency for a in predators])

    plt.scatter(x, y, c=resources, cmap="viridis")
    plt.colorbar(label="Resources")
    for pos, _ in GRAVITY_CENTERS:
        plt.plot(pos[0], pos[1], 'ro')
    plt.title(f"{label} (Endosymbiosis: {model.endosymbiosis_events}, Organelles: {organelle_count})")
    plt.show()

    return {
        "endosymbiosis_events": model.endosymbiosis_events,
        "organelle_agents": organelle_count,
        "avg_resources": np.mean(resources),
        "avg_motility": avg_motility,
        "avg_efficiency": avg_efficiency,
        "population": len(predators)
    }

# Run simulations
print("Normal Gravity with Competing Sweet Spots")
normal_results = run_simulation(G_NORMAL, "Normal Gravity")
print(f"Endosymbiosis Events: {normal_results['endosymbiosis_events']}, "
      f"Organelle Agents: {normal_results['organelle_agents']}, "
      f"Avg Resources: {normal_results['avg_resources']:.2f}, "
      f"Avg Motility: {normal_results['avg_motility']:.2f}, "
      f"Avg Efficiency: {normal_results['avg_efficiency']:.2f}, "
      f"Population: {normal_results['population']}")

print("\nMicrogravity")
micro_results = run_simulation(G_MICRO, "Microgravity")
print(f"Endosymbiosis Events: {micro_results['endosymbiosis_events']}, "
      f"Organelle Agents: {micro_results['organelle_agents']}, "
      f"Avg Resources: {micro_results['avg_resources']:.2f}, "
      f"Avg Motility: {micro_results['avg_motility']:.2f}, "
      f"Avg Efficiency: {micro_results['avg_efficiency']:.2f}, "
      f"Population: {micro_results['population']}")
# Out:
# Normal Gravity with Competing Sweet Spots
# Error placing agent 110 at [100.          60.39217802]: Point out of bounds, and space non-toroidal.
# Error placing agent 141 at [100.          61.72468253]: Point out of bounds, and space non-toroidal.
# Error placing agent 167 at [100.          61.03803584]: Point out of bounds, and space non-toroidal.
# Error placing agent 451 at [100.          60.55505198]: Point out of bounds, and space non-toroidal.
# Error placing agent 613 at [100.          61.27355389]: Point out of bounds, and space non-toroidal.
# Error placing agent 709 at [100.          59.72556202]: Point out of bounds, and space non-toroidal.
# Error placing agent 733 at [100.          61.27976435]: Point out of bounds, and space non-toroidal.
# Error placing agent 1251 at [100.          61.01740351]: Point out of bounds, and space non-toroidal.
# Error placing agent 1428 at [100.          60.83493641]: Point out of bounds, and space non-toroidal.
# Error placing agent 1454 at [100.          59.60918954]: Point out of bounds, and space non-toroidal.
# Error placing agent 1661 at [100.          96.63302302]: Point out of bounds, and space non-toroidal.
# Error placing agent 2446 at [100.         59.9022156]: Point out of bounds, and space non-toroidal.
# Error placing agent 2540 at [100.          59.56813779]: Point out of bounds, and space non-toroidal.
# Error placing agent 2590 at [100.          59.23556029]: Point out of bounds, and space non-toroidal.
# Error placing agent 2791 at [100.          59.44128886]: Point out of bounds, and space non-toroidal.
# Error placing agent 2987 at [100.          60.24779253]: Point out of bounds, and space non-toroidal.
# Error placing agent 3404 at [100.          59.71956532]: Point out of bounds, and space non-toroidal.
# Error placing agent 4571 at [100.          59.36898564]: Point out of bounds, and space non-toroidal.
# Error placing agent 5245 at [100.          60.31688408]: Point out of bounds, and space non-toroidal.
# Error placing agent 5286 at [100.         59.2182649]: Point out of bounds, and space non-toroidal.
# Error placing agent 5810 at [100.          58.66750535]: Point out of bounds, and space non-toroidal.
# Error placing agent 5934 at [100.          60.96748972]: Point out of bounds, and space non-toroidal.
# Error placing agent 6044 at [100.          59.44216234]: Point out of bounds, and space non-toroidal.
# Error placing agent 6105 at [100.          60.23306681]: Point out of bounds, and space non-toroidal.
# Error placing agent 6374 at [100.          95.61179405]: Point out of bounds, and space non-toroidal.
# Error placing agent 6558 at [100.          61.28933336]: Point out of bounds, and space non-toroidal.
# Error placing agent 7108 at [100.          60.11150733]: Point out of bounds, and space non-toroidal.
# Error placing agent 7392 at [100.          59.66203273]: Point out of bounds, and space non-toroidal.
# Error placing agent 7501 at [100.          94.41743672]: Point out of bounds, and space non-toroidal.
# Error placing agent 7591 at [100.          59.92062546]: Point out of bounds, and space non-toroidal.
# Error placing agent 7688 at [100.          59.99351135]: Point out of bounds, and space non-toroidal.
# Error placing agent 8238 at [100.          59.29514099]: Point out of bounds, and space non-toroidal.
# Error placing agent 8294 at [100.          60.94291198]: Point out of bounds, and space non-toroidal.
# Error placing agent 8564 at [100.         60.6996478]: Point out of bounds, and space non-toroidal.
# Error placing agent 8602 at [100.          58.02709087]: Point out of bounds, and space non-toroidal.
# Error placing agent 8801 at [100.          60.10957053]: Point out of bounds, and space non-toroidal.
# Error placing agent 9060 at [100.          59.80674526]: Point out of bounds, and space non-toroidal.
# Error placing agent 9201 at [100.          60.91645703]: Point out of bounds, and space non-toroidal.
# Error placing agent 9282 at [100.          61.70042932]: Point out of bounds, and space non-toroidal.
# Error placing agent 9488 at [100.          60.30055019]: Point out of bounds, and space non-toroidal.
# Error placing agent 11062 at [100.          59.34607703]: Point out of bounds, and space non-toroidal.
# Endosymbiosis Events: 7, Organelle Agents: 7, Avg Resources: 87.30, Avg Motility: 1.01, Avg Efficiency: 1.13, Population: 11462
#
# Microgravity
# Error placing agent 1877 at [100.          71.60413603]: Point out of bounds, and space non-toroidal.
# Endosymbiosis Events: 34, Organelle Agents: 34, Avg Resources: 63.83, Avg Motility: 1.02, Avg Efficiency: 1.47, Population: 2004
